# %% [markdown]
# # Example plotting script

# %%
from src.postprocess.plot_tracing_results import plot_tracing_results

# %%
example_df = pd.read_csv("outputs/bongos_to_cello/metrics_blocks.csv")
out_file_path = "outputs/bongos_to_cello/sims_blocks.pdf"
plot_tracing_results(example_df, highlight_layers=["block_up1"], left_reference_idx=0, right_reference_idx=8, out_file_path=out_file_path)

# %%
example_df = pd.read_csv("outputs/bongos_to_cello/metrics_transformers.csv")
out_file_path = "outputs/bongos_to_cello/sims_transformers.pdf"
plot_tracing_results(example_df, highlight_layers=["tf_up1tf5"], left_reference_idx=0, right_reference_idx=7, out_file_path=out_file_path, excluded_layers=["block_up1"])

# %%
example_df = pd.read_csv("outputs/bongos_to_cello/metrics_attentions.csv")
out_file_path = "outputs/bongos_to_cello/sims_attentions.pdf"
plot_tracing_results(example_df, highlight_layers=["tf_up1tf5"], left_reference_idx=0, right_reference_idx=4, out_file_path=out_file_path, excluded_layers=["block_up1"])

# %% [markdown]
# # Male to female

# %%
example_df = pd.read_csv("outputs/male_to_female/metrics_blocks.csv")
out_file_path = "docs/res/male_blocks.png"
plot_tracing_results(example_df, highlight_layers=["block_up1"], left_reference_idx=0, right_reference_idx=8, out_file_path=out_file_path, yticks=[0.1, 0.2, 0.3])

# %%
example_df = pd.read_csv("outputs/male_to_female/metrics_transformers.csv")
out_file_path = "docs/res/male_transformers.png"
plot_tracing_results(example_df, highlight_layers=["tf_up1tf10"], left_reference_idx=0, right_reference_idx=7, out_file_path=out_file_path, yticks=[0.1, 0.2, 0.3], excluded_layers=["block_up1"])

# %%
example_df = pd.read_csv("outputs/male_to_female/metrics_attentions.csv")
out_file_path = "docs/res/male_attentions.png"
plot_tracing_results(example_df, highlight_layers=["attn_up1tf10attn0"], left_reference_idx=0, right_reference_idx=3, out_file_path=out_file_path, yticks=[0.1, 0.2, 0.3], excluded_layers=["block_up1", "tf_up1tf10"])

# %% [markdown]
# # Saxophone

# %%
example_df = pd.read_csv("outputs/saxophone_to_drums/metrics_blocks.csv")
out_file_path = "docs/res/saxophone_blocks.png"
plot_tracing_results(example_df, highlight_layers=["block_up1"], left_reference_idx=0, right_reference_idx=8, out_file_path=out_file_path, yticks=[0.1, 0.2, 0.3])

# %%
example_df = pd.read_csv("outputs/saxophone_to_drums/metrics_transformers.csv")
out_file_path = "docs/res/saxophone_transformers.png"
plot_tracing_results(example_df, highlight_layers=["tf_up1tf5", "tf_up1tf10"], left_reference_idx=0, right_reference_idx=7, out_file_path=out_file_path, yticks=[0.1, 0.2, 0.3], excluded_layers=["block_up1"])

# %%
import pandas as pd

# %%
example_df = pd.read_csv("outputs/saxophone_to_drums/metrics_attentions.csv")
out_file_path = "docs/res/saxophone_attentions.png"
plot_tracing_results(example_df, highlight_layers=["attn_up1tf5attn0tf10attn0"], left_reference_idx=0, right_reference_idx=6, out_file_path=out_file_path, yticks=[0.1, 0.2, 0.3], excluded_layers=["block_up1", "tf_up1tf5", "tf_up1tf10"])
